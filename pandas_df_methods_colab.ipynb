# %% [markdown]
# <a href="https://colab.research.google.com/github/SrinathMLOps/MLPractise/blob/main/pandas_df_methods_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🧪 Pandas DataFrame Methods: Before & After with Code
# This notebook demonstrates common pandas `df.` methods using a sample dataset. Each cell shows the original data, method usage, and result.

# %%
import pandas as pd

# Sample dataset
data = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eve"],
    "Age": [25, 30, None, 45, 30],
    "Gender": ["F", "M", "M", "M", "F"],
    "Salary": [50000, 60000, 70000, 80000, None],
    "Department": ["HR", "IT", "IT", "Finance", "HR"]
}
df = pd.DataFrame(data)
df
# Out:
#       Name   Age Gender   Salary Department
# 0    Alice  25.0      F  50000.0         HR
# 1      Bob  30.0      M  60000.0         IT
# 2  Charlie   NaN      M  70000.0         IT
# 3    David  45.0      M  80000.0    Finance
# 4      Eve  30.0      F      NaN         HR

# %% [markdown]
# ## 🔹 Method: `df.info()`
# ```python
# df.info()
# ```

# %%
# BEFORE
import pandas as pd
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Age': [25, 30, None, 45, 30],
    'Gender': ['F', 'M', 'M', 'M', 'F'],
    'Salary': [50000, 60000, 70000, 80000, None],
    'Department': ['HR', 'IT', 'IT', 'Finance', 'HR']
}
df = pd.DataFrame(data)
df
# Out:
#       Name   Age Gender   Salary Department
# 0    Alice  25.0      F  50000.0         HR
# 1      Bob  30.0      M  60000.0         IT
# 2  Charlie   NaN      M  70000.0         IT
# 3    David  45.0      M  80000.0    Finance
# 4      Eve  30.0      F      NaN         HR

# %%
# AFTER APPLYING df.info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        5 non-null      object
#  1   Age         4 non-null      float64
#  2   Gender      5 non-null      object
#  3   Salary      4 non-null      float64
#  4   Department  5 non-null      object
# dtypes: float64(2), object(3)
# memory usage: 332.0+ bytes

# %% [markdown]
# ## 🔹 Method: `df.fillna()`
# ```python
# df['Age'].fillna(df['Age'].mean(), inplace=True)
# df['Salary'].fillna(df['Salary'].median(), inplace=True)
# ```

# %%
# BEFORE
import pandas as pd
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Age': [25, 30, None, 45, 30],
    'Gender': ['F', 'M', 'M', 'M', 'F'],
    'Salary': [50000, 60000, 70000, 80000, None],
    'Department': ['HR', 'IT', 'IT', 'Finance', 'HR']
}
df = pd.DataFrame(data)
df
# Out:
#       Name   Age Gender   Salary Department
# 0    Alice  25.0      F  50000.0         HR
# 1      Bob  30.0      M  60000.0         IT
# 2  Charlie   NaN      M  70000.0         IT
# 3    David  45.0      M  80000.0    Finance
# 4      Eve  30.0      F      NaN         HR

# %%
# AFTER APPLYING df.fillna()
df['Age'].fillna(df['Age'].mean(), inplace=True)
df['Salary'].fillna(df['Salary'].median(), inplace=True)
# Out:
# <ipython-input-23-140617315>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].mean(), inplace=True)
# <ipython-input-23-140617315>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Salary'].fillna(df['Salary'].median(), inplace=True)

# %% [markdown]
# ## 🔹 Method: `df.dropna()`
# ```python
# df.dropna()
# ```

# %%
# BEFORE
import pandas as pd
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Age': [25, 30, None, 45, 30],
    'Gender': ['F', 'M', 'M', 'M', 'F'],
    'Salary': [50000, 60000, 70000, 80000, None],
    'Department': ['HR', 'IT', 'IT', 'Finance', 'HR']
}
df = pd.DataFrame(data)
df
# Out:
#       Name   Age Gender   Salary Department
# 0    Alice  25.0      F  50000.0         HR
# 1      Bob  30.0      M  60000.0         IT
# 2  Charlie   NaN      M  70000.0         IT
# 3    David  45.0      M  80000.0    Finance
# 4      Eve  30.0      F      NaN         HR

# %%
# AFTER APPLYING df.dropna()
df.dropna()
# Out:
#     Name   Age Gender   Salary Department
# 0  Alice  25.0      F  50000.0         HR
# 1    Bob  30.0      M  60000.0         IT
# 3  David  45.0      M  80000.0    Finance

# %% [markdown]
# ## 🔹 Method: `df['Gender'].value_counts()`
# ```python
# df['Gender'].value_counts()
# ```

# %%
# BEFORE
import pandas as pd
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Age': [25, 30, None, 45, 30],
    'Gender': ['F', 'M', 'M', 'M', 'F'],
    'Salary': [50000, 60000, 70000, 80000, None],
    'Department': ['HR', 'IT', 'IT', 'Finance', 'HR']
}
df = pd.DataFrame(data)
df
# Out:
#       Name   Age Gender   Salary Department
# 0    Alice  25.0      F  50000.0         HR
# 1      Bob  30.0      M  60000.0         IT
# 2  Charlie   NaN      M  70000.0         IT
# 3    David  45.0      M  80000.0    Finance
# 4      Eve  30.0      F      NaN         HR

# %%
# AFTER APPLYING df['Gender'].value_counts()
df['Gender'].value_counts()
# Out:
# Gender
# M    3
# F    2
# Name: count, dtype: int64

# %% [markdown]
# ## 🔹 Method: `df['Department'].unique()`
# ```python
# df['Department'].unique()
# ```

# %%
# BEFORE
import pandas as pd
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Age': [25, 30, None, 45, 30],
    'Gender': ['F', 'M', 'M', 'M', 'F'],
    'Salary': [50000, 60000, 70000, 80000, None],
    'Department': ['HR', 'IT', 'IT', 'Finance', 'HR']
}
df = pd.DataFrame(data)
df
# Out:
#       Name   Age Gender   Salary Department
# 0    Alice  25.0      F  50000.0         HR
# 1      Bob  30.0      M  60000.0         IT
# 2  Charlie   NaN      M  70000.0         IT
# 3    David  45.0      M  80000.0    Finance
# 4      Eve  30.0      F      NaN         HR

# %%
# AFTER APPLYING df['Department'].unique()
df['Department'].unique()
# Out:
# array(['HR', 'IT', 'Finance'], dtype=object)

# %% [markdown]
# ## 🔹 Method: `df.describe()`
# ```python
# df.describe()
# ```

# %%
# BEFORE
import pandas as pd
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Age': [25, 30, None, 45, 30],
    'Gender': ['F', 'M', 'M', 'M', 'F'],
    'Salary': [50000, 60000, 70000, 80000, None],
    'Department': ['HR', 'IT', 'IT', 'Finance', 'HR']
}
df = pd.DataFrame(data)
df
# Out:
#       Name   Age Gender   Salary Department
# 0    Alice  25.0      F  50000.0         HR
# 1      Bob  30.0      M  60000.0         IT
# 2  Charlie   NaN      M  70000.0         IT
# 3    David  45.0      M  80000.0    Finance
# 4      Eve  30.0      F      NaN         HR

# %%
# AFTER APPLYING df.describe()
df.describe()
# Out:
#              Age        Salary
# count   4.000000      4.000000
# mean   32.500000  65000.000000
# std     8.660254  12909.944487
# min    25.000000  50000.000000
# 25%    28.750000  57500.000000
# 50%    30.000000  65000.000000
# 75%    33.750000  72500.000000
# max    45.000000  80000.000000

# %% [markdown]
# ## 🔹 Method: `df.rename()`
# ```python
# df.rename(columns={'Salary': 'AnnualSalary'})
# ```

# %%
# BEFORE
import pandas as pd
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Age': [25, 30, None, 45, 30],
    'Gender': ['F', 'M', 'M', 'M', 'F'],
    'Salary': [50000, 60000, 70000, 80000, None],
    'Department': ['HR', 'IT', 'IT', 'Finance', 'HR']
}
df = pd.DataFrame(data)
df
# Out:
#       Name   Age Gender   Salary Department
# 0    Alice  25.0      F  50000.0         HR
# 1      Bob  30.0      M  60000.0         IT
# 2  Charlie   NaN      M  70000.0         IT
# 3    David  45.0      M  80000.0    Finance
# 4      Eve  30.0      F      NaN         HR

# %%
# AFTER APPLYING df.rename()
df.rename(columns={'Salary': 'AnnualSalary'})
# Out:
#       Name   Age Gender  AnnualSalary Department
# 0    Alice  25.0      F       50000.0         HR
# 1      Bob  30.0      M       60000.0         IT
# 2  Charlie   NaN      M       70000.0         IT
# 3    David  45.0      M       80000.0    Finance
# 4      Eve  30.0      F           NaN         HR

# %% [markdown]
# ## 🔹 Method: `df.drop()`
# ```python
# df.drop('Department', axis=1)
# ```

# %%
# BEFORE
import pandas as pd
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Age': [25, 30, None, 45, 30],
    'Gender': ['F', 'M', 'M', 'M', 'F'],
    'Salary': [50000, 60000, 70000, 80000, None],
    'Department': ['HR', 'IT', 'IT', 'Finance', 'HR']
}
df = pd.DataFrame(data)
df
# Out:
#       Name   Age Gender   Salary Department
# 0    Alice  25.0      F  50000.0         HR
# 1      Bob  30.0      M  60000.0         IT
# 2  Charlie   NaN      M  70000.0         IT
# 3    David  45.0      M  80000.0    Finance
# 4      Eve  30.0      F      NaN         HR

# %%
# AFTER APPLYING df.drop()
df.drop('Department', axis=1)
# Out:
#       Name   Age Gender   Salary
# 0    Alice  25.0      F  50000.0
# 1      Bob  30.0      M  60000.0
# 2  Charlie   NaN      M  70000.0
# 3    David  45.0      M  80000.0
# 4      Eve  30.0      F      NaN

# %% [markdown]
# ## 🔹 Method: `df.replace()`
# ```python
# df.replace({'M': 'Male', 'F': 'Female'})
# ```

# %%
# BEFORE
import pandas as pd
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Age': [25, 30, None, 45, 30],
    'Gender': ['F', 'M', 'M', 'M', 'F'],
    'Salary': [50000, 60000, 70000, 80000, None],
    'Department': ['HR', 'IT', 'IT', 'Finance', 'HR']
}
df = pd.DataFrame(data)
df
# Out:
#       Name   Age Gender   Salary Department
# 0    Alice  25.0      F  50000.0         HR
# 1      Bob  30.0      M  60000.0         IT
# 2  Charlie   NaN      M  70000.0         IT
# 3    David  45.0      M  80000.0    Finance
# 4      Eve  30.0      F      NaN         HR

# %%
# AFTER APPLYING df.replace()
df.replace({'M': 'Male', 'F': 'Female'})
# Out:
#       Name   Age  Gender   Salary Department
# 0    Alice  25.0  Female  50000.0         HR
# 1      Bob  30.0    Male  60000.0         IT
# 2  Charlie   NaN    Male  70000.0         IT
# 3    David  45.0    Male  80000.0    Finance
# 4      Eve  30.0  Female      NaN         HR

# %% [markdown]
# ## 🔹 Method: `df.astype()`
# ```python
# df['Age'] = df['Age'].fillna(0).astype(int)
# ```

# %%
# BEFORE
import pandas as pd
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Age': [25, 30, None, 45, 30],
    'Gender': ['F', 'M', 'M', 'M', 'F'],
    'Salary': [50000, 60000, 70000, 80000, None],
    'Department': ['HR', 'IT', 'IT', 'Finance', 'HR']
}
df = pd.DataFrame(data)
df
# Out:
#       Name   Age Gender   Salary Department
# 0    Alice  25.0      F  50000.0         HR
# 1      Bob  30.0      M  60000.0         IT
# 2  Charlie   NaN      M  70000.0         IT
# 3    David  45.0      M  80000.0    Finance
# 4      Eve  30.0      F      NaN         HR

# %%
# AFTER APPLYING df.astype()
df['Age'] = df['Age'].fillna(0).astype(int)

# %% [markdown]
# ## 🔹 Method: `df.sort_values()`
# ```python
# df.sort_values('Salary')
# ```

# %%
# BEFORE
import pandas as pd
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Age': [25, 30, None, 45, 30],
    'Gender': ['F', 'M', 'M', 'M', 'F'],
    'Salary': [50000, 60000, 70000, 80000, None],
    'Department': ['HR', 'IT', 'IT', 'Finance', 'HR']
}
df = pd.DataFrame(data)
df
# Out:
#       Name   Age Gender   Salary Department
# 0    Alice  25.0      F  50000.0         HR
# 1      Bob  30.0      M  60000.0         IT
# 2  Charlie   NaN      M  70000.0         IT
# 3    David  45.0      M  80000.0    Finance
# 4      Eve  30.0      F      NaN         HR

# %%
# AFTER APPLYING df.sort_values()
df.sort_values('Salary')
# Out:
#       Name   Age Gender   Salary Department
# 0    Alice  25.0      F  50000.0         HR
# 1      Bob  30.0      M  60000.0         IT
# 2  Charlie   NaN      M  70000.0         IT
# 3    David  45.0      M  80000.0    Finance
# 4      Eve  30.0      F      NaN         HR

# %% [markdown]
# ## 🔹 Method: `df.groupby()`
# ```python
# df.groupby('Gender')['Salary'].mean()
# ```

# %%
# BEFORE
import pandas as pd
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Age': [25, 30, None, 45, 30],
    'Gender': ['F', 'M', 'M', 'M', 'F'],
    'Salary': [50000, 60000, 70000, 80000, None],
    'Department': ['HR', 'IT', 'IT', 'Finance', 'HR']
}
df = pd.DataFrame(data)
df
# Out:
#       Name   Age Gender   Salary Department
# 0    Alice  25.0      F  50000.0         HR
# 1      Bob  30.0      M  60000.0         IT
# 2  Charlie   NaN      M  70000.0         IT
# 3    David  45.0      M  80000.0    Finance
# 4      Eve  30.0      F      NaN         HR

# %%
# AFTER APPLYING df.groupby()
df.groupby('Gender')['Salary'].mean()
# Out:
# Gender
# F    50000.0
# M    70000.0
# Name: Salary, dtype: float64

# %% [markdown]
# ✔️ Now you're ready to master these functions in real-world data analysis workflows.
